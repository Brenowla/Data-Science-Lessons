# %%
import numpy as np

# %%
numpyArray = np.arange(1000000)
pyList = list(range(1000000))

# %%
# %time for _ in range(100): numpyArray *= 2
# Out:
# Wall time: 47 ms

# %%
# %time for _ in range(100): pyList = [x*2 for x in pyList]
# Out:
# Wall time: 13 s

# %%
km = np.array([5,6,8,1])
km = np.loadtxt("data/carros-km.txt")

# %%
anos = np.loadtxt("data/carros-anos.txt", dtype = int)

# %%
km_media = km / (2021 - anos)

# %%
km_media.dtype
# Out:
# dtype('float64')

# %%
idade = 2021-anos

# %%
idade
# Out:
# array([18, 30, 31,  2, 15,  9,  2, 12, 11, 10, 19, 14, 20,  2, 12,  5,  9,
#         2,  5,  4, 19,  2, 27, 30,  2,  2,  5,  2, 19, 30, 24, 26,  3, 30,
#         7, 26,  2,  2, 12,  2,  8, 18,  2, 19,  2, 19, 17, 20,  2, 18, 12,
#        15, 21, 15, 11, 27, 14,  2,  2,  2,  2,  2,  4, 10, 20, 25,  2, 27,
#         2, 14, 27, 14, 24, 15,  8, 27, 13, 13,  2,  2, 22, 14, 28, 26,  2,
#         2,  5, 10,  2, 19,  8,  4,  5, 13,  3, 18, 18, 17, 11,  2, 15, 20,
#         2,  6,  3,  4, 29, 20, 28, 26, 18,  7, 13,  8,  2,  4,  2,  2, 15,
#         6, 14, 16,  4, 23,  2, 22,  2, 12, 18, 27,  2, 27,  2,  6, 25, 24,
#        28,  2, 29, 26,  2, 31,  2,  2, 30, 31,  9, 14,  8, 21, 19, 25, 25,
#         6, 28,  8,  8, 12,  2,  2, 19, 24, 23, 17, 25,  6,  5, 16, 22, 26,
#        28, 17,  8, 23,  3,  2,  3,  2, 31, 12, 31, 15, 19, 30, 29,  2,  2,
#        16, 11,  2,  5,  2, 11, 27, 20,  7, 25, 28, 28, 20,  2,  2,  2, 14,
# ...

# %%
dados = np.array([km, anos])

# %%
dados
# Out:
# array([[4.44100e+04, 5.71200e+03, 3.71230e+04, 0.00000e+00, 2.57570e+04,
#         1.07280e+04, 0.00000e+00, 7.75990e+04, 9.91970e+04, 3.79780e+04,
#         1.28590e+04, 8.05200e+03, 8.97730e+04, 0.00000e+00, 4.14570e+04,
#         1.15607e+05, 4.64490e+04, 0.00000e+00, 3.70860e+04, 1.51730e+04,
#         1.01193e+05, 0.00000e+00, 9.80790e+04, 1.02959e+05, 0.00000e+00,
#         0.00000e+00, 5.79500e+03, 0.00000e+00, 5.88480e+04, 9.43810e+04,
#         3.01630e+04, 5.33320e+04, 1.77200e+04, 3.38080e+04, 9.06840e+04,
#         4.39750e+04, 0.00000e+00, 0.00000e+00, 5.52600e+03, 0.00000e+00,
#         9.34150e+04, 4.07620e+04, 0.00000e+00, 8.63020e+04, 0.00000e+00,
#         9.75500e+03, 6.99450e+04, 2.39500e+03, 0.00000e+00, 8.03490e+04,
#         8.55540e+04, 5.04960e+04, 6.77160e+04, 9.39470e+04, 3.53450e+04,
#         8.10070e+04, 1.19513e+05, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 1.18895e+05, 4.85090e+04, 1.00912e+05,
# ...

# %%
dados.shape
# Out:
# (2, 258)

# %%
km_media = dados[0]/(2021 - dados[1])

# %%
km_media
# Out:
# array([2.46722222e+03, 1.90400000e+02, 1.19751613e+03, 0.00000000e+00,
#        1.71713333e+03, 1.19200000e+03, 0.00000000e+00, 6.46658333e+03,
#        9.01790909e+03, 3.79780000e+03, 6.76789474e+02, 5.75142857e+02,
#        4.48865000e+03, 0.00000000e+00, 3.45475000e+03, 2.31214000e+04,
#        5.16100000e+03, 0.00000000e+00, 7.41720000e+03, 3.79325000e+03,
#        5.32594737e+03, 0.00000000e+00, 3.63255556e+03, 3.43196667e+03,
#        0.00000000e+00, 0.00000000e+00, 1.15900000e+03, 0.00000000e+00,
#        3.09726316e+03, 3.14603333e+03, 1.25679167e+03, 2.05123077e+03,
#        5.90666667e+03, 1.12693333e+03, 1.29548571e+04, 1.69134615e+03,
#        0.00000000e+00, 0.00000000e+00, 4.60500000e+02, 0.00000000e+00,
#        1.16768750e+04, 2.26455556e+03, 0.00000000e+00, 4.54221053e+03,
#        0.00000000e+00, 5.13421053e+02, 4.11441176e+03, 1.19750000e+02,
#        0.00000000e+00, 4.46383333e+03, 7.12950000e+03, 3.36640000e+03,
# ...

# %%
km_media.T
# Out:
# array([2.46722222e+03, 1.90400000e+02, 1.19751613e+03, 0.00000000e+00,
#        1.71713333e+03, 1.19200000e+03, 0.00000000e+00, 6.46658333e+03,
#        9.01790909e+03, 3.79780000e+03, 6.76789474e+02, 5.75142857e+02,
#        4.48865000e+03, 0.00000000e+00, 3.45475000e+03, 2.31214000e+04,
#        5.16100000e+03, 0.00000000e+00, 7.41720000e+03, 3.79325000e+03,
#        5.32594737e+03, 0.00000000e+00, 3.63255556e+03, 3.43196667e+03,
#        0.00000000e+00, 0.00000000e+00, 1.15900000e+03, 0.00000000e+00,
#        3.09726316e+03, 3.14603333e+03, 1.25679167e+03, 2.05123077e+03,
#        5.90666667e+03, 1.12693333e+03, 1.29548571e+04, 1.69134615e+03,
#        0.00000000e+00, 0.00000000e+00, 4.60500000e+02, 0.00000000e+00,
#        1.16768750e+04, 2.26455556e+03, 0.00000000e+00, 4.54221053e+03,
#        0.00000000e+00, 5.13421053e+02, 4.11441176e+03, 1.19750000e+02,
#        0.00000000e+00, 4.46383333e+03, 7.12950000e+03, 3.36640000e+03,
# ...

# %%
valor = np.loadtxt("data/carros-valor.txt")

# %%
dataset = np.column_stack((anos, km, valor))

# %%
dataset
# Out:
# array([[2.0030000e+03, 4.4410000e+04, 8.8078640e+04],
#        [1.9910000e+03, 5.7120000e+03, 1.0616194e+05],
#        [1.9900000e+03, 3.7123000e+04, 7.2832160e+04],
#        [2.0190000e+03, 0.0000000e+00, 1.2454907e+05],
#        [2.0060000e+03, 2.5757000e+04, 9.2612100e+04],
#        [2.0120000e+03, 1.0728000e+04, 9.7497730e+04],
#        [2.0190000e+03, 0.0000000e+00, 5.6445200e+04],
#        [2.0090000e+03, 7.7599000e+04, 1.1231044e+05],
#        [2.0100000e+03, 9.9197000e+04, 1.2071627e+05],
#        [2.0110000e+03, 3.7978000e+04, 7.6566490e+04],
#        [2.0020000e+03, 1.2859000e+04, 7.1647590e+04],
#        [2.0070000e+03, 8.0520000e+03, 7.3919530e+04],
#        [2.0010000e+03, 8.9773000e+04, 1.1273299e+05],
#        [2.0190000e+03, 0.0000000e+00, 5.3183380e+04],
#        [2.0090000e+03, 4.1457000e+04, 1.2748842e+05],
#        [2.0160000e+03, 1.1560700e+05, 5.9910400e+04],
#        [2.0120000e+03, 4.6449000e+04, 6.1118590e+04],
# ...

# %%
np.mean(dataset, axis = 0)
# Out:
# array([ 2007.51162791, 44499.41472868, 98960.51310078])

# %%
np.std(dataset, axis = 0)
# Out:
# array([9.70703915e+00, 3.98598270e+04, 2.97541012e+04])

# %%
dataset.sum(axis = 0)
# Out:
# array([  517938.        , 11480849.        , 25531812.37999999])
